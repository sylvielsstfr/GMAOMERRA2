# %% [markdown]
# # To merge datasets on atmosphere
#
# - author : Sylvie Dagoret-Campagne
# - date   : April 26th 2018
# - affiliation : LAL/IN2P3/CNRS
# - update : November 2018
# - used in April 2018 for CTIO
# - used in November 2018 for StarDice
#
#
# - update December 5th 2022 for LSST

# %%
import os,sys
import pandas as pd
import numpy as np

# %%
#path='datasets_2017'
#path='datasets_2018'
#path='datasets_2022'
path='datasets_2021'

# %%
#files=['MERRA2_2017_inst1_2d_asm_Nx_M2I1NXASM_ctio_AllYear.csv',
#       'MERRA2_2017_tavg1_2d_aer_Nx_M2T1NXAER_ctio_AllYear.csv',
#       'MERRA2_2017_tavg1_2d_rad_Nx_M2T1NXRAD_ctio_AllYear.csv']
#files=['MERRA2_2018_inst1_2d_asm_Nx_M2I1NXASM_ohp_AllYear.csv',
#       'MERRA2_2018_tavg1_2d_aer_Nx_M2T1NXAER_ohp_AllYear.csv',
#       'MERRA2_2018_tavg1_2d_rad_Nx_M2T1NXRAD_ohp_AllYear.csv']

#files=['MERRA2_2022_inst1_2d_asm_Nx_M2I1NXASM_lsst_AllYear.csv',
#       'MERRA2_2022_tavg1_2d_aer_Nx_M2T1NXAER_lsst_AllYear.csv',
#       'MERRA2_2022_tavg1_2d_rad_Nx_M2T1NXRAD_lsst_AllYear.csv']

files=['MERRA2_2021_inst1_2d_asm_Nx_M2I1NXASM_lsst_AllYear.csv',
       'MERRA2_2021_tavg1_2d_aer_Nx_M2T1NXAER_lsst_AllYear.csv',
       'MERRA2_2021_tavg1_2d_rad_Nx_M2T1NXRAD_lsst_AllYear.csv']

# %%
#output_file='MERRA2_2017_M2I1NXASM_M2T1NXAER_M2T1NXRAD_ctio_AllYear.csv'
#output_file='MERRA2_2018_M2I1NXASM_M2T1NXAER_M2T1NXRAD_ohp_AllYear.csv'
#output_file='MERRA2_2022_M2I1NXASM_M2T1NXAER_M2T1NXRAD_lsst_AllYear.csv'
output_file='MERRA2_2021_M2I1NXASM_M2T1NXAER_M2T1NXRAD_lsst_AllYear.csv'

# %% [markdown]
# # Read independant dataset

# %%
df1=pd.read_csv(os.path.join(path,files[0]))
df2=pd.read_csv(os.path.join(path,files[1]))
df3=pd.read_csv(os.path.join(path,files[2]))

# %% [markdown]
# # Specify which column is the index
#
# - the index is the time

# %%
df1.set_index("time",inplace=True)
df1.head()
# Out:
#                             PS       T10M        T2M        TO3       TOX  \
# time
# 2021-01-01 00:00:00  78309.336  289.73587  289.72906  247.26114  0.005301
# 2021-01-01 01:00:00  78353.440  288.45830  288.14820  246.95404  0.005294
# 2021-01-01 02:00:00  78399.140  289.09607  288.32602  246.62802  0.005287
# 2021-01-01 03:00:00  78434.100  289.61584  288.91230  246.08704  0.005275
# 2021-01-01 04:00:00  78439.300  289.57867  288.79303  245.58127  0.005264
#
#                      TQI  TQL        TQV         TS      U10M       U2M  \
# time
# 2021-01-01 00:00:00  0.0  0.0   9.219856  289.53670  1.417040  1.029335
# 2021-01-01 01:00:00  0.0  0.0   9.299347  287.69740 -0.640781 -0.321693
# 2021-01-01 02:00:00  0.0  0.0   9.733832  286.42050 -1.040606 -0.651973
# 2021-01-01 03:00:00  0.0  0.0  10.086275  285.64383 -0.592623 -0.392119
# 2021-01-01 04:00:00  0.0  0.0  10.178970  284.94794 -0.186442 -0.133778
#
#                          U50M      V10M       V2M      V50M
# time
# 2021-01-01 00:00:00  1.653588  1.271824  0.941790  1.593075
# 2021-01-01 01:00:00 -0.997959  0.720388  0.370704  1.075519
# 2021-01-01 02:00:00 -1.313788  0.071793  0.050780  0.098654
# 2021-01-01 03:00:00 -0.690463 -0.301546 -0.178987 -0.397412
# 2021-01-01 04:00:00 -0.234019 -0.381485 -0.213192 -0.497831

# %%
df2.set_index("time",inplace=True)
df2.head()
# Out:
#                      TOTANGSTR  TOTEXTTAU  TOTSCATAU
# time
# 2021-01-01 00:30:00   1.196867   0.056970   0.053770
# 2021-01-01 01:30:00   1.198094   0.057817   0.054558
# 2021-01-01 02:30:00   1.201883   0.060025   0.056720
# 2021-01-01 03:30:00   1.209316   0.062329   0.059037
# 2021-01-01 04:30:00   1.218950   0.064500   0.061218

# %%
df3.set_index("time",inplace=True)
df3.head()
# Out:
#                      TAUHGH  TAULOW  TAUMID  TAUTOT
# time
# 2021-01-01 00:30:00     0.0     0.0     0.0     0.0
# 2021-01-01 01:30:00     0.0     0.0     0.0     0.0
# 2021-01-01 02:30:00     0.0     0.0     0.0     0.0
# 2021-01-01 03:30:00     0.0     0.0     0.0     0.0
# 2021-01-01 04:30:00     0.0     0.0     0.0     0.0

# %% [markdown]
# # concatenate in vertical the 2 first dataset and reorder by index

# %%
#df12=pd.concat([df1,df2]).sort_index()
#df12

# %%
df23=pd.concat([df2,df3],axis=1).sort_index()

# %%
df23.head()
# Out:
#                      TOTANGSTR  TOTEXTTAU  TOTSCATAU  TAUHGH  TAULOW  TAUMID  \
# time
# 2021-01-01 00:30:00   1.196867   0.056970   0.053770     0.0     0.0     0.0
# 2021-01-01 01:30:00   1.198094   0.057817   0.054558     0.0     0.0     0.0
# 2021-01-01 02:30:00   1.201883   0.060025   0.056720     0.0     0.0     0.0
# 2021-01-01 03:30:00   1.209316   0.062329   0.059037     0.0     0.0     0.0
# 2021-01-01 04:30:00   1.218950   0.064500   0.061218     0.0     0.0     0.0
#
#                      TAUTOT
# time
# 2021-01-01 00:30:00     0.0
# 2021-01-01 01:30:00     0.0
# 2021-01-01 02:30:00     0.0
# 2021-01-01 03:30:00     0.0
# 2021-01-01 04:30:00     0.0

# %%
df123=pd.concat([df1,df23],axis=0).sort_index()

# %%
df123
# Out:
#                             PS       T10M        T2M        TO3       TOX  \
# time
# 2021-01-01 00:00:00  78309.336  289.73587  289.72906  247.26114  0.005301
# 2021-01-01 00:30:00        NaN        NaN        NaN        NaN       NaN
# 2021-01-01 01:00:00  78353.440  288.45830  288.14820  246.95404  0.005294
# 2021-01-01 01:30:00        NaN        NaN        NaN        NaN       NaN
# 2021-01-01 02:00:00  78399.140  289.09607  288.32602  246.62802  0.005287
# ...                        ...        ...        ...        ...       ...
# 2021-12-31 21:30:00        NaN        NaN        NaN        NaN       NaN
# 2021-12-31 22:00:00  78375.710  293.70453  294.89526  257.20810  0.005525
# 2021-12-31 22:30:00        NaN        NaN        NaN        NaN       NaN
# 2021-12-31 23:00:00  78375.620  292.20227  292.69092  257.28720  0.005526
# 2021-12-31 23:30:00        NaN        NaN        NaN        NaN       NaN
#
#                      TQI           TQL       TQV         TS      U10M  ...  \
# time                                                                   ...
# 2021-01-01 00:00:00  0.0  0.000000e+00  9.219856  289.53670  1.417040  ...
# 2021-01-01 00:30:00  NaN           NaN       NaN        NaN       NaN  ...
# 2021-01-01 01:00:00  0.0  0.000000e+00  9.299347  287.69740 -0.640781  ...
# 2021-01-01 01:30:00  NaN           NaN       NaN        NaN       NaN  ...
# 2021-01-01 02:00:00  0.0  0.000000e+00  9.733832  286.42050 -1.040606  ...
# ...                  ...           ...       ...        ...       ...  ...
# 2021-12-31 21:30:00  NaN           NaN       NaN        NaN       NaN  ...
# 2021-12-31 22:00:00  0.0  7.337078e-08  5.651654  299.88538  4.196548  ...
# 2021-12-31 22:30:00  NaN           NaN       NaN        NaN       NaN  ...
# 2021-12-31 23:00:00  0.0  0.000000e+00  5.101372  294.21707  2.821155  ...
# 2021-12-31 23:30:00  NaN           NaN       NaN        NaN       NaN  ...
#
#                          V10M       V2M      V50M  TOTANGSTR  TOTEXTTAU  \
# time
# 2021-01-01 00:00:00  1.271824  0.941790  1.593075        NaN        NaN
# 2021-01-01 00:30:00       NaN       NaN       NaN   1.196867   0.056970
# 2021-01-01 01:00:00  0.720388  0.370704  1.075519        NaN        NaN
# 2021-01-01 01:30:00       NaN       NaN       NaN   1.198094   0.057817
# 2021-01-01 02:00:00  0.071793  0.050780  0.098654        NaN        NaN
# ...                       ...       ...       ...        ...        ...
# 2021-12-31 21:30:00       NaN       NaN       NaN   1.299958   0.046939
# 2021-12-31 22:00:00  2.128071  1.739041  2.022682        NaN        NaN
# 2021-12-31 22:30:00       NaN       NaN       NaN   1.300608   0.044456
# 2021-12-31 23:00:00  1.867919  1.512907  1.822366        NaN        NaN
# 2021-12-31 23:30:00       NaN       NaN       NaN   1.311450   0.041640
#
#                      TOTSCATAU  TAUHGH  TAULOW  TAUMID  TAUTOT
# time
# 2021-01-01 00:00:00        NaN     NaN     NaN     NaN     NaN
# 2021-01-01 00:30:00   0.053770     0.0     0.0     0.0     0.0
# 2021-01-01 01:00:00        NaN     NaN     NaN     NaN     NaN
# 2021-01-01 01:30:00   0.054558     0.0     0.0     0.0     0.0
# 2021-01-01 02:00:00        NaN     NaN     NaN     NaN     NaN
# ...                        ...     ...     ...     ...     ...
# 2021-12-31 21:30:00   0.043829     0.0     0.0     0.0     0.0
# 2021-12-31 22:00:00        NaN     NaN     NaN     NaN     NaN
# 2021-12-31 22:30:00   0.041350     0.0     0.0     0.0     0.0
# 2021-12-31 23:00:00        NaN     NaN     NaN     NaN     NaN
# 2021-12-31 23:30:00   0.038609     0.0     0.0     0.0     0.0
#
# [11664 rows x 22 columns]

# %%
#df123=pd.concat([df12,df3]).sort_index()

# %%
#df=df123.reindex_axis(['ps','pwv','ozone',
#                    'TOTEXTTAU','TOTANGSTR','TOTSCATAU',
#                    'TAUTOT','TAUHGH','TAUMID','TAULOW'], axis=1)
df=df123.reindex(['PS','TQV','TO3',
                  'TOTEXTTAU','TOTANGSTR','TOTSCATAU',
                  'TAUTOT','TAUHGH','TAUMID','TAULOW'], axis=1)
df
# Out:
#                             PS       TQV        TO3  TOTEXTTAU  TOTANGSTR  \
# time
# 2021-01-01 00:00:00  78309.336  9.219856  247.26114        NaN        NaN
# 2021-01-01 00:30:00        NaN       NaN        NaN   0.056970   1.196867
# 2021-01-01 01:00:00  78353.440  9.299347  246.95404        NaN        NaN
# 2021-01-01 01:30:00        NaN       NaN        NaN   0.057817   1.198094
# 2021-01-01 02:00:00  78399.140  9.733832  246.62802        NaN        NaN
# ...                        ...       ...        ...        ...        ...
# 2021-12-31 21:30:00        NaN       NaN        NaN   0.046939   1.299958
# 2021-12-31 22:00:00  78375.710  5.651654  257.20810        NaN        NaN
# 2021-12-31 22:30:00        NaN       NaN        NaN   0.044456   1.300608
# 2021-12-31 23:00:00  78375.620  5.101372  257.28720        NaN        NaN
# 2021-12-31 23:30:00        NaN       NaN        NaN   0.041640   1.311450
#
#                      TOTSCATAU  TAUTOT  TAUHGH  TAUMID  TAULOW
# time
# 2021-01-01 00:00:00        NaN     NaN     NaN     NaN     NaN
# 2021-01-01 00:30:00   0.053770     0.0     0.0     0.0     0.0
# 2021-01-01 01:00:00        NaN     NaN     NaN     NaN     NaN
# 2021-01-01 01:30:00   0.054558     0.0     0.0     0.0     0.0
# 2021-01-01 02:00:00        NaN     NaN     NaN     NaN     NaN
# ...                        ...     ...     ...     ...     ...
# 2021-12-31 21:30:00   0.043829     0.0     0.0     0.0     0.0
# 2021-12-31 22:00:00        NaN     NaN     NaN     NaN     NaN
# 2021-12-31 22:30:00   0.041350     0.0     0.0     0.0     0.0
# 2021-12-31 23:00:00        NaN     NaN     NaN     NaN     NaN
# 2021-12-31 23:30:00   0.038609     0.0     0.0     0.0     0.0
#
# [11664 rows x 10 columns]

# %%
df.to_csv(output_file)
